# %% [markdown]
# # ___________Text Classification Using Multinomial Naive Bayes Classifier__

# %% [markdown]
# # Importing Modules

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import os                                               
import nltk                                                
nltk.download('stopwords')
from nltk.corpus import stopwords                   
from collections import Counter                            
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import scikitplot as skplt
from nltk import word_tokenize
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\akshay\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Getting Desired X_train and Y_train from given data

# %%
stop=set(stopwords.words("english"))                         #stopwords as a set
block_words = set(['last','better',
              'never','every','even','two','good','used'
              ,'first','need','going','must','really',
              'might','well','without','made','give',
              'look','try','far','less','seem','new',
              'make','many','way','since','using','take'
              ,'help','thanks','send','free','may','see',
              'much','want','find','would','one','like',
              'get','use','also','could','say','us','go',
              'please','said','set','got','sure','come',
              'lot','seems','able','anything','put','apr',
              'gmt','article','nntp-posting-host:','anyone',
              'time','still','back','another','read','number',
              'file','let','cannot','told','files','yet','per'])

# %%
allWords=[]                                             
mainPath="20_newsgroups"                                    
for subFolder in os.listdir(mainPath):              
    subFolderPath=mainPath+"\\"+subFolder                   
    for file in os.listdir(subFolderPath):                  
        fileObj=open(subFolderPath+"\\"+file,"r")           
        fileContent=fileObj.read()                          
        words=word_tokenize(fileContent)      
        for w in words:                          
            w=w.lower()                                     
            if w in stop or w in block_words or len(w)<=2 or not(w.isalpha()):
                continue
            allWords.append(w)
        fileObj.close()
Words=Counter(allWords)
sortedWords=Words.most_common()                             #sorting words acc. to decreasing freq.,as list of word, freq.

# %%
x_axis=[]                                                   #current word
y_axis=[]                                                   #frequency
for i in range(2000,3000):                                  #since words after 3000 have frequency lesser than 100, we shall
    x_axis.append(i)                                        #take the first 3000 words only. Although, the score would increase
    y_axis.append(sortedWords[i][1])                        #with no. of features(words).However, prediction time will be high
plt.plot(x_axis,y_axis)                                     #if no. of words increase.
plt.xlabel("Word_Number")
plt.ylabel("Word_Frequency")
plt.grid()
plt.show()

# %%
#since words till 10000 have a frequency of >20, we will take these as feature names
feature_names=[]
feature_dict={}                                          #for faster search(dictionary)
for i in range(5000):
    feature_names.append(sortedWords[i][0])
    feature_dict[sortedWords[i][0]]=i                    #dict keys are words and values are indices
print(feature_names)
# Out:
# ['subject', 'lines', 'date', 'newsgroups', 'path', 'organization', 'writes', 'references', 'news', 'sender', 'people', 'university', 'know', 'think', 'xref', 'system', 'usenet', 'god', 'uunet', 'right', 'distribution', 'max', 'world', 'rochester', 'work', 'something', 'problem', 'christian', 'gatech', 'believe', 'computer', 'years', 'udel', 'information', 'government', 'state', 'point', 'question', 'things', 'windows', 'usa', 'david', 'someone', 'year', 'thing', 'case', 'program', 'fact', 'data', 'part', 'available', 'software', 'drive', 'version', 'space', 'etc', 'science', 'little', 'around', 'however', 'power', 'john', 'long', 'law', 'usc', 'different', 'best', 'day', 'fri', 'true', 'probably', 'tue', 'least', 'group', 'enough', 'actually', 'public', 'tell', 'game', 'course', 'support', 'car', 'great', 'systems', 'jesus', 'though', 'says', 'run', 'either', 'life', 'mean', 'nothing', 'list', 'sun', 'next', 'else', 'possible', 'real', 'rather', 'name', 'key', 'card', 'second', 'research', 'thu', 'reason', 'hard', 'call', 'wrong', 'old', 'post', 'internet', 'called', 'mon', 'others', 'yes', 'line', 'message', 'keep', 'bill', 'found', 'man', 'problems', 'done', 'person', 'mark', 'looking', 'maybe', 'technology', 'seen', 'bit', 'order', 'example', 'team', 'place', 'image', 'email', 'end', 'following', 'bad', 'center', 'ever', 'access', 'general', 'quite', 'wrote', 'always', 'high', 'heard', 'thought', 'evidence', 'means', 'trying', 'whether', 'control', 'israel', 'book', 'chip', 'three', 'children', 'wed', 'opinions', 'given', 'jews', 'michael', 'human', 'away', 'phone', 'idea', 'today', 'national', 'several', 'start', 'kind', 'gun', 'getting', 'times', 'keywords', 'left', 'word', 'mail', 'window', 'note', 'questions', 'big', 'home', 'remember', 'info', 'makes', 'change', 'president', 'saying', 'paul', 'wupost', 'based', 'price', 'user', 'source', 'mac', 'perhaps', 'agate', 'department', 'rights', 'frank', 'net', 'code', 'standard', 'ask', 'institute', 'steve', 'already', 'dos', 'local', 'american', 'money', 'stuff', 'games', 'answer', 'small', 'graphics', 'disk', 'mike', 'large', 'running', 'ago', 'agree', 'interested', 'issue', 'address', 'days', 'came', 'bible', 'war', 'buy', 'matter', 'approved', 'whole', 'pretty', 'show', 'network', 'works', 'jim', 'states', 'hope', 'fax', 'claim', 'original', 'current', 'sale', 'feel', 'care', 'religion', 'play', 'fire', 'live', 'machine', 'understand', 'open', 'box', 'love', 'often', 'everyone', 'fbi', 'simply', 'everything', 'full', 'history', 'important', 'college', 'rutgers', 'church', 'programs', 'memory', 'robert', 'canada', 'went', 'april', 'including', 'speed', 'engineering', 'almost', 'truth', 'mind', 'certainly', 'started', 'wanted', 'turkish', 'earth', 'armenian', 'caen', 'guess', 'posting', 'instead', 'comes', 'unix', 'area', 'pay', 'encryption', 'making', 'clipper', 'include', 'men', 'type', 'later', 'ftp', 'house', 'apple', 'video', 'although', 'side', 'working', 'service', 'white', 'christ', 'color', 'christians', 'hand', 'server', 'display', 'value', 'death', 'anyway', 'country', 'dept', 'cause', 'jewish', 'unless', 'win', 'within', 'company', 'private', 'scsi', 'words', 'school', 'consider', 'black', 'difference', 'sat', 'hell', 'copy', 'california', 'health', 'opinion', 'tried', 'police', 'armenians', 'faith', 'sort', 'write', 'deal', 'sense', 'anybody', 'single', 'cost', 'contact', 'clear', 'view', 'clinton', 'hedrick', 'morality', 'political', 'talking', 'likely', 'james', 'similar', 'light', 'argument', 'check', 'especially', 'ibm', 'summary', 'couple', 'major', 'brian', 'nice', 'happened', 'package', 'san', 'objective', 'certain', 'religious', 'services', 'night', 'saw', 'simple', 'koresh', 'city', 'via', 'correct', 'press', 'known', 'dead', 'took', 'stop', 'women', 'exactly', 'security', 'asked', 'tin', 'provide', 'killed', 'among', 'thus', 'society', 'sound', 'situation', 'body', 'sorry', 'moral', 'taken', 'dave', 'fine', 'monitor', 'common', 'driver', 'statement',  ...

# %%
x=[]
y=[]                                              
mainPath="20_newsgroups"
arrayOfAllZeros=np.zeros(5000)
for subFolder in os.listdir(mainPath):                        
    subFolderPath=mainPath+"\\"+subFolder                   
    for file in os.listdir(subFolderPath):                  
        fileObj=open(subFolderPath+"\\"+file,"r")           
        words=((fileObj.read()).strip()).split()
        curCounts=arrayOfAllZeros.copy()                           #this will contain x of current file
        y.append(subFolder)                                        #subFolder is the type of article eg.alt.atheism
        for w in words:
            w=w.lower()
            if w in feature_dict:
                curCounts[feature_dict[w]]+=1
        x.append(curCounts)
        fileObj.close()
x=np.array(x)
y=np.array(y)
print(x.shape,type(x))
print(y.shape,type(y))
# Out:
# (19997, 5000) <class 'numpy.ndarray'>
# (19997,) <class 'numpy.ndarray'>

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)       #splitting data into train and test

# %% [markdown]
# # Classifying using inbuilt Multinomial Naive Bayes in SKLearn

# %%
clf=MultinomialNB()
clf.fit(x_train,y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
y_pred=clf.predict(x_test)
print(y_pred)
print(set(y_pred))
# Out:
# ['comp.windows.x' 'sci.med' 'talk.politics.guns' ...
#  'soc.religion.christian' 'rec.autos' 'sci.space']
# {'rec.sport.baseball', 'sci.electronics', 'rec.motorcycles', 'rec.sport.hockey', 'sci.med', 'talk.politics.guns', 'comp.sys.mac.hardware', 'soc.religion.christian', 'comp.os.ms-windows.misc', 'misc.forsale', 'talk.politics.mideast', 'comp.windows.x', 'talk.politics.misc', 'rec.autos', 'comp.graphics', 'sci.space', 'talk.religion.misc', 'comp.sys.ibm.pc.hardware', 'sci.crypt', 'alt.atheism'}

# %%
clf.score(x_test,y_test)
# Out:
# 0.78525

# %%
#Confusion Matrix:    
skplt.metrics.plot_confusion_matrix(y_test,y_pred,figsize=(15,15)) #as we can see most of the predictions belong to correct class(highest values along diagonal)

# %%
classification_report(y_test,y_pred)
# Out:
# '                          precision    recall  f1-score   support\n\n             alt.atheism       0.70      0.76      0.73       193\n           comp.graphics       0.67      0.68      0.67       201\n comp.os.ms-windows.misc       0.70      0.80      0.74       197\ncomp.sys.ibm.pc.hardware       0.67      0.70      0.68       182\n   comp.sys.mac.hardware       0.73      0.80      0.77       196\n          comp.windows.x       0.83      0.74      0.78       196\n            misc.forsale       0.76      0.73      0.75       214\n               rec.autos       0.82      0.82      0.82       221\n         rec.motorcycles       0.86      0.89      0.87       224\n      rec.sport.baseball       0.93      0.91      0.92       194\n        rec.sport.hockey       0.92      0.96      0.94       191\n               sci.crypt       0.90      0.92      0.91       194\n         sci.electronics       0.74      0.69      0.72       196\n                 sci.med       0.90      0.83      0.86       210\n               sci.space       0.88      0.87      0.88       195\n  soc.religion.christian       0.81      0.84      0.83       199\n      talk.politics.guns       0.69      0.85      0.76       203\n   talk.politics.mideast       0.89      0.86      0.88       216\n      talk.politics.misc       0.68      0.63      0.65       190\n      talk.religion.misc       0.57      0.38      0.45       188\n\n                accuracy                           0.79      4000\n               macro avg       0.78      0.78      0.78      4000\n            weighted avg       0.78      0.79      0.78      4000\n'

# %% [markdown]
# # My Own Implementation of Naive Bayes for Text Classification

# %%
#fit function
def fit(x_train,y_train):
    result={}                                             #dictionary
    classes=set(y_train)                                  #set of all classes
    result["total_data"]=len(y_train)                     #total no. of data points 
    for i in classes:                                     #for each class i
        result[i]={}                                      #create a dictionary for class i
        c=(y==i)                                          #True wherever y belongs to class i, False otherwise
        curFiles=x[c]                                     #getting all files(data points) belonging to class i
        totalWordsInCurClass=0                            #total no. of words in current class
        for j in range(len(feature_names)):               #for each word j
            result[i][j]=curFiles[:,j].sum()              #no. of occurences of word no. j in files of class i
            totalWordsInCurClass+=result[i][j]
        result[i]["total_words"]=totalWordsInCurClass
        result[i]["total_count"]=len(curFiles)            #no. of data points belonging to current class
    return result

# %%
#function to calculate probability:
def probability(result,x,a):                         #a is the current class whose prob.we want to calculate, x is data point
    product=np.log((result[a]["total_count"])/(result["total_data"]))
    for i in range(len(feature_names)):
        if x[i]==0:
            continue
        numerator=result[a][i]+1
        denominator=result[a]["total_words"]+len(feature_names)
        prob=np.log(numerator/denominator)
        product+=prob
    return product

# %%
#predicting for a single data point:
def predict_single_point(result,x_test):             #x_test is a single point
    max_prob=float('-inf')                           #dummy value(as log will give -ve, we take sufficiently high -ve no.)
    max_prob_class=-1                                #dummy value
    for i in result.keys():
        if i=="total_data":
            continue
        cur_prob=probability(result,x_test,i)
        if cur_prob>max_prob:
            max_prob=cur_prob
            max_prob_class=i
    return max_prob_class

# %%
#predict function:
def predict(result,x_test):
    y_pred=[]
    for i in x_test:
        y_pred.append(predict_single_point(result,i))
    return np.array(y_pred)

# %%
result=fit(x_train,y_train)
y_pred2=predict(result,x_test)
print(y_pred2)
print(set(y_pred2))
# Out:
# ['comp.windows.x' 'sci.med' 'talk.politics.guns' ...
#  'soc.religion.christian' 'rec.motorcycles' 'sci.space']
# {'rec.sport.baseball', 'sci.electronics', 'rec.motorcycles', 'rec.sport.hockey', 'sci.med', 'talk.politics.guns', 'comp.sys.mac.hardware', 'soc.religion.christian', 'comp.os.ms-windows.misc', 'misc.forsale', 'talk.politics.mideast', 'comp.windows.x', 'talk.politics.misc', 'rec.autos', 'comp.graphics', 'sci.space', 'talk.religion.misc', 'comp.sys.ibm.pc.hardware', 'sci.crypt', 'alt.atheism'}

# %%
#Confusion Matrix:    
skplt.metrics.plot_confusion_matrix(y_test,y_pred2,figsize=(15,15))

# %%
classification_report(y_test,y_pred2)       #all scores are better than those of SKLearn MNB (see f1 score)
# Out:
# '                          precision    recall  f1-score   support\n\n             alt.atheism       0.79      0.87      0.82       193\n           comp.graphics       0.72      0.79      0.75       201\n comp.os.ms-windows.misc       0.77      0.85      0.81       197\ncomp.sys.ibm.pc.hardware       0.78      0.79      0.78       182\n   comp.sys.mac.hardware       0.82      0.87      0.85       196\n          comp.windows.x       0.92      0.77      0.84       196\n            misc.forsale       0.79      0.83      0.81       214\n               rec.autos       0.87      0.89      0.88       221\n         rec.motorcycles       0.92      0.95      0.94       224\n      rec.sport.baseball       0.95      0.95      0.95       194\n        rec.sport.hockey       0.96      0.97      0.97       191\n               sci.crypt       0.92      0.95      0.93       194\n         sci.electronics       0.84      0.76      0.79       196\n                 sci.med       0.93      0.87      0.90       210\n               sci.space       0.92      0.90      0.91       195\n  soc.religion.christian       0.91      0.90      0.91       199\n      talk.politics.guns       0.77      0.89      0.83       203\n   talk.politics.mideast       0.91      0.88      0.89       216\n      talk.politics.misc       0.75      0.69      0.72       190\n      talk.religion.misc       0.73      0.55      0.63       188\n\n                accuracy                           0.85      4000\n               macro avg       0.85      0.85      0.85      4000\n            weighted avg       0.85      0.85      0.85      4000\n'
